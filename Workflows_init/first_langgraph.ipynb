# %%
from IPython.display import Image, display

# %%
import lg_with_tuto as tuto

# View
display(Image(tuto.graph.get_graph().draw_mermaid_png()))

# %%
import lg_with_preview as prev

# View
display(Image(prev.graph.get_graph().draw_mermaid_png()))
