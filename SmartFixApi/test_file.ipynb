# %%
from OllamaCore.sf_rag_engine import SfRagEngine

force_initialize = False # PUT 'True' the first time to populate chroma_db

sf_rag_engine = SfRagEngine(force_initialize)
# Out:
# chargement des documents présents dans {documents_path}
# Initialisation de ChromaDB...
# Initialisation de la fonction d'embedding via Ollama...
# Création ou chargement de la collection : smartfix_collection
# Nombre de documents stockés : 7011

# %%
sf_rag_engine.initialize_langgraph()

question = "Comment accéder au gestionnaire des tâches de Ubuntu ?"
print(question)

answer = sf_rag_engine.query_rag(question)
print(answer)
# Out:
# Initialisation des composants LangGraph...
# Graphe RAG initialisé avec succès!
# Comment accéder au gestionnaire des tâches de Ubuntu ?
# Recherche de documents pour: Comment accéder au gestionnaire des tâches de Ubuntu ?
# /home/nicolascassonnet/Documents/WORK/SmartFix/SmartFixApi/OllamaCore/sf_rag_engine.py:159: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   ollama_embeddings = OllamaEmbeddings(model=self.embedding_model)
# ...
