# %%
from OllamaCore.sf_rag_engine import SfRagEngine

sf_rag_engine = SfRagEngine()
# Out:
# chargement des documents présents dans {documents_path}
# Initialisation de ChromaDB...
# Initialisation de la fonction d'embedding via Ollama...
# Création ou chargement de la collection : smartfix_collection
# Chargement du fichier : /home/nicolascassonnet/Documents/WORK/SmartFix/DATA/Documents/Ubuntu 2204 france.pdf
# Stockage des chunks du fichier /home/nicolascassonnet/Documents/WORK/SmartFix/DATA/Documents/Ubuntu 2204 france.pdf dans ChromaDB...
# ...chunks 80 à 90 sur 82...
# Chargement du fichier : /home/nicolascassonnet/Documents/WORK/SmartFix/DATA/Documents/Premiers pas avec Ubuntu 13.10.pdf
# Stockage des chunks du fichier /home/nicolascassonnet/Documents/WORK/SmartFix/DATA/Documents/Premiers pas avec Ubuntu 13.10.pdf dans ChromaDB...
# ...chunks 640 à 650 sur 641...
# Chargement du fichier : /home/nicolascassonnet/Documents/WORK/SmartFix/DATA/Documents/ubuntu_tutorial.pdf
# ...
